# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/players_3120_original.csv')

# %%
df.head()
# Out:
#                    name  Age Overall rating Potential  \
# 0  15 Ronaldinho CAM ST   34             78        78
# 1  O. Hutchinson RM CAM   19             65        81
# 2            Brahim CAM   23             82        86
# 3          K. Wätjen CM   17             62        80
# 4       A. Güler CAM RM   18             77        88
#
#                   Team & Contract      ID         Height         Weight  \
# 0          Querétaro\n2014 ~ 2016   28130   182cm / 6'0"  76kg / 168lbs
# 1       Ipswich Town\n2022 ~ 2025  260145   174cm / 5'9"  65kg / 143lbs
# 2        Real Madrid\n2019 ~ 2027  231410   170cm / 5'7"  68kg / 150lbs
# 3  Borussia Dortmund\n2024 ~ 2028   70728  178cm / 5'10"  72kg / 159lbs
# 4        Real Madrid\n2023 ~ 2029  264309   175cm / 5'9"  70kg / 154lbs
#
#     foot  Best overall Best position  Growth   Value   Wage Release clause  \
# 0  Right            77           CAM       0   €4.1M   €45K             €0
# 1   Left            67           CAM      16   €1.8M    €3K          €4.5M
# 2  Right            84           CAM       4  €43.5M  €145K         €92.4M
# 3  Right            65           CAM      18     €1M   €900          €2.3M
# 4   Left            79           CAM      11    €22M   €41K         €49.5M
#
#    Total attacking Crossing Finishing Heading accuracy Short passing Volleys  \
# 0              367       84        69               50            82      82
# 1              266       48        53               49            66      50
# 2              328       75        76               30            83      64
# 3              257       48        53               45            67      44
# 4              340       80        68               41            81      70
#
#    Total skill Dribbling Curve FK Accuracy Long passing Ball control  \
# 0          430        86    86          87           81           90
# 1          304        69    52          50           65           68
# 2          379        84    74          61           75           85
# 3          292        66    52          43           65           66
# 4          403        83    84          76           79           81
#
#    Total movement Acceleration Sprint speed Agility Reactions Balance  \
# 0             313           50           48      73        70      72
# 1             366           76           69      81        61      79
# 2             429           85           85      89        79      91
# 3             356           77           68      78        59      74
# 4             380           75           69      82        69      85
#
#    Total power Shot power Jumping Stamina Strength Long shots  \
# 0          314         74      55      41       72         72
# 1          272         62      56      63       47         44
# 2          332         73      60      68       55         76
# 3          267         48      58      63       51         47
# 4          308         72      50      70       43         73
#
#    Total mentality Aggression Interceptions Att. Position Vision Penalties  \
# 0              319         60            25            66     82        86
# 1              264         41            37            60     65        61
# 2              294         44            33            78     81        58
# 3              263         47            54            54     59        49
# 4              316         42            55            68     80        71
#
#   Composure  Total defending Defensive awareness Standing tackle  \
# 0         0               78                  25              28
# 1        63              140                  40              49
# 2        79               84                  40              23
# 3        49              161                  50              55
# 4        77              155                  52              57
#
#   Sliding tackle  Total goalkeeping GK Diving GK Handling GK Kicking  \
# 0             25                 54         7          14         13
# 1             51                 39        10           7          9
# 2             21                 51        13           9         13
# 3             56                 48         9          13          7
# 4             46                 58        13          10         11
#
#   GK Positioning GK Reflexes  Total stats  Base stats  \
# 0              6          14         1875         377
# 1              5           8         1651         351
# 2             10           6         1897         409
# 3             11           8         1644         353
# 4             14          10         1960         405
#
#    International reputation  Pace / Diving  Shooting / Handling  \
# 0                         3             49                   72
# 1                         1             72                   54
# 2                         1             85                   74
# 3                         1             72                   50
# 4                         1             72                   70
#
#    Passing / Kicking  Dribbling / Reflexes  Defending / Pace  Unnamed: 64
# 0                 83                    84                28          NaN
# 1                 61                    70                44          NaN
# 2                 78                    85                31          NaN
# 3                 59                    66                52          NaN
# 4                 80                    81                52          NaN

# %%
df.shape
# Out:
# (3120, 65)

# %%
df.describe()
# Out:
#                Age             ID  Best overall       Growth  Total attacking  \
# count  3120.000000    3120.000000   3120.000000  3120.000000      3120.000000
# mean     24.218590  236637.525321     74.368910     5.875962       291.675641
# std       4.876116   39161.333184      6.430639     5.714962        72.207131
# min      16.000000      41.000000     49.000000     0.000000        51.000000
# 25%      20.000000  224285.000000     70.000000     0.000000       267.000000
# 50%      23.000000  243017.000000     75.000000     5.000000       304.000000
# 75%      27.000000  262621.000000     79.000000    10.000000       339.000000
# max      44.000000  279922.000000     93.000000    25.000000       440.000000
#
#        Total skill  Total movement  Total power  Total mentality  \
# count  3120.000000     3120.000000  3120.000000      3120.000000
# mean    307.003846      349.397756   328.516026       293.083333
# std      75.263189       52.477820    50.544401        63.164889
# min      61.000000      133.000000   146.000000        72.000000
# 25%     280.000000      325.000000   299.000000       268.000000
# 50%     321.000000      359.000000   335.000000       303.000000
# 75%     357.000000      385.000000   366.000000       334.000000
# max     465.000000      462.000000   442.000000       417.000000
#
#        Total defending  Total goalkeeping  Total stats   Base stats  \
# count      3120.000000        3120.000000  3120.000000  3120.000000
# mean        155.752564          72.398077  1797.827244   394.946474
# std          64.891734          79.925173   258.036837    38.493322
# min          24.000000          13.000000   843.000000   253.000000
# 25%          97.000000          47.000000  1670.750000   369.000000
# 50%         174.000000          52.000000  1839.000000   398.000000
# 75%         212.000000          57.000000  1973.250000   422.000000
# max         269.000000         433.000000  2330.000000   500.000000
#
#        International reputation  Pace / Diving  Shooting / Handling  \
# count               3120.000000    3120.000000          3120.000000
# mean                   1.450962      73.015385            61.509936
# std                    0.804862      10.379235            14.111539
# min                    1.000000      29.000000            21.000000
# 25%                    1.000000      67.000000            53.000000
# 50%                    1.000000      74.000000            64.000000
# 75%                    2.000000      80.000000            72.000000
# max                    5.000000      97.000000            93.000000
#
#        Passing / Kicking  Dribbling / Reflexes  Defending / Pace  Unnamed: 64
# count        3120.000000           3120.000000       3120.000000          0.0
# mean           65.975321             71.527244         54.649359          NaN
# std             9.621618              8.620042         18.068982          NaN
# min            31.000000             34.000000         16.000000          NaN
# 25%            60.000000             66.750000         38.000000          NaN
# 50%            67.000000             72.000000         58.000000          NaN
# 75%            73.000000             77.000000         70.000000          NaN
# max            94.000000             94.000000         89.000000          NaN

# %% [markdown]
# LIMPIEZA DE DATOS

# %%
#Numero total de valores nulos
df.isnull().sum().sum()
# Out:
# 3120

# %%
#Eliminacion de la columna Unnamed: 64, para deshacernos de los valores nulos
df.drop(columns='Unnamed: 64', inplace=True)

# %%
#Comprobacion de que al eliminar la columna Unnamed:64 deja de haber valores nulos en el DataFrame
df.isnull().sum().sum()
# Out:
# 0

# %%
#Convierte todos los nombres en minúsculas
#Reemplaza cualquier espacio o /, en un guión bajo
#Susttituye los espacios en blanco por guiones bajos
df.columns = df.columns.str.lower().str.replace(' / ','_').str.replace(' ','_')
df.columns
# Out:
# Index(['name', 'age', 'overall_rating', 'potential', 'team_&_contract', 'id',
#        'height', 'weight', 'foot', 'best_overall', 'best_position', 'growth',
#        'value', 'wage', 'release_clause', 'total_attacking', 'crossing',
#        'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'total_skill', 'dribbling', 'curve', 'fk_accuracy', 'long_passing',
#        'ball_control', 'total_movement', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'total_power', 'shot_power',
#        'jumping', 'stamina', 'strength', 'long_shots', 'total_mentality',
#        'aggression', 'interceptions', 'att._position', 'vision', 'penalties',
#        'composure', 'total_defending', 'defensive_awareness',
#        'standing_tackle', 'sliding_tackle', 'total_goalkeeping', 'gk_diving',
#        'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes',
#        'total_stats', 'base_stats', 'international_reputation', 'pace_diving',
#        'shooting_handling', 'passing_kicking', 'dribbling_reflexes',
#        'defending_pace'],
#       dtype='object')

# %% [markdown]
# Con este paso he tratado de normalizar los nombres de cada una de las variables que hay en las columnas del DataFrame, para mejorar la accesibilidad a los datos y evitar posibles errores al manipular dichas variables en el codigo.
#
# Para ello, he aplicado:
#     -Conversión de todas las letras a minúsculas: Para evitar inconsistencias por diferencias de capitalización
#     -Reemplazo de caracteres especiales como "/" y espacios
#
#         -Se sustituyeron los espacios por guiones bajos "_" para mejorar la legibilidad y evitar problemas al acceder a las columnas.
#         -Se reemplazaron los caracteres "/" por "_", ya que estos símbolos pueden generar errores en el codigo o crear dificultades en algunas librerias.
#
# Por lo tanto, al usar esta limpieza en las variables de las columnas, se obtienen beneficios como:
#
#     -Mayor coherencia en los nombres de columnas, eliminando ambigüedades y asegurando uniformidad en el dataset.
#     -Evita problemas al referenciar columnas en código, especialmente en análisis y modelos de machine learning.
#     -Mejora la compatibilidad con herramientas de análisis de datos, ya que algunas librerías pueden no manejar bien       nombres con espacios o caracteres especiales.

# %%
import re

#Lista con todas las posibles posiciones de los jugadores, usada para identificar y extrar las posiciones de cada uno
#de los jugadores
posiciones = ['GK', 'LB', 'LWB', 'RB', 'RWB', 'CB', 'CAM', 'CM', 'CDM', 'LW', 'RW' ,'LM', 'RM', 'LF', 'RF', 'CF', 'ST']
def split_name_position(fila):
    fila = re.sub(r'\d+', '', fila)  #Elimina todos lo numeros
    palabra = fila.split()  #Dividir la cadena en palabras individuales (espacios)
    nombre_completo = [part for part in palabra if part not in posiciones]  #Guardar las palabras que no son una posicion
    posicion = [part for part in palabra if part in posiciones]  #Guardar las palabras que sí son una posicion
    

    nombre = ' '.join(nombre_completo) #Une las palabras para construir el nombre del futbolista
    pos = ', '.join(posicion) #Une las palabras (separadas por comas si es necesario) para contruir la posicion/es
    return pd.Series([nombre, pos])

#Eliminamos la columna name, y añadimos dos nuevas columnas, llamadas "player_name" y "position"
df[['player_name', 'position']] = df['name'].apply(split_name_position)
df.drop('name', axis=1, inplace=True)

# %% [markdown]
# Como se podía observar en el dataset original, la columna "name" contenía tanto el nombre del jugador como su/s posicion/es. Si una columna contiene mas de un tipo de informacion, es difícil de manejar en análisis estadísticos y modelos de Machine Leanning. Por lo tanto, he optado por separar la columna "name" en dos columnas específicas:
#
#     -"player_name" -> Contiene el nombre del jugador
#     -"position" -> Contiene la/s posicion/es en las que cada jugador puede jugar.

# %%
#Comprobacion de que el codigo anterior ha creado correctamente las 2 nuevas columnas
df
# Out:
#       age overall_rating potential  \
# 0      34             78        78
# 1      19             65        81
# 2      23             82        86
# 3      17             62        80
# 4      18             77        88
# ...   ...            ...       ...
# 3115   19             65        78
# 3116   20             62        72
# 3117   19           69+1      82+1
# 3118   17             54        69
# 3119   24             73        78
#
#                                   team_&_contract      id         height  \
# 0                          Querétaro\n2014 ~ 2016   28130   182cm / 6'0"
# 1                       Ipswich Town\n2022 ~ 2025  260145   174cm / 5'9"
# 2                        Real Madrid\n2019 ~ 2027  231410   170cm / 5'7"
# 3                  Borussia Dortmund\n2024 ~ 2028   70728  178cm / 5'10"
# 4                        Real Madrid\n2023 ~ 2029  264309   175cm / 5'9"
# ...                                           ...     ...            ...
# 3115  DSC Arminia Bielefeld\nJun 30, 2024 On loan  270403  178cm / 5'10"
# 3116                     Saarbrücken\n2023 ~ 2024  270461  180cm / 5'11"
# 3117                Eldense\nJun 30, 2024 On loan  270529   190cm / 6'3"
# 3118               Raków Częstochowa\n2023 ~ 2026  270594   189cm / 6'2"
# 3119                        Cagliari\n2022 ~ 2026  270597   187cm / 6'2"
#
#              weight   foot  best_overall best_position  growth   value   wage  \
# 0     76kg / 168lbs  Right            77           CAM       0   €4.1M   €45K
# 1     65kg / 143lbs   Left            67           CAM      16   €1.8M    €3K
# 2     68kg / 150lbs  Right            84           CAM       4  €43.5M  €145K
# 3     72kg / 159lbs  Right            65           CAM      18     €1M   €900
# 4     70kg / 154lbs   Left            79           CAM      11    €22M   €41K
# ...             ...    ...           ...           ...     ...     ...    ...
# 3115  69kg / 152lbs  Right            66           CDM      13   €1.6M    €3K
# 3116  81kg / 179lbs   Left            62           LWB      10   €825K    €1K
# 3117  85kg / 187lbs  Right            69            GK      13   €2.9M    €2K
# 3118  88kg / 194lbs  Right            56            ST      15   €250K   €500
# 3119  80kg / 176lbs  Right            74           CDM       5   €4.2M   €16K
#
#      release_clause  total_attacking crossing finishing heading_accuracy  \
# 0                €0              367       84        69               50
# 1             €4.5M              266       48        53               49
# 2            €92.4M              328       75        76               30
# 3             €2.3M              257       48        53               45
# 4            €49.5M              340       80        68               41
# ...             ...              ...      ...       ...              ...
# 3115             €0              254       58        45               50
# 3116          €1.4M              241       60        30               54
# 3117             €0               70       15        10               10
# 3118          €506K              223       31        55               56
# 3119          €7.9M              293       57        57               60
#
#      short_passing volleys  total_skill dribbling curve fk_accuracy  \
# 0               82      82          430        86    86          87
# 1               66      50          304        69    52          50
# 2               83      64          379        84    74          61
# 3               67      44          292        66    52          43
# 4               81      70          403        83    84          76
# ...            ...     ...          ...       ...   ...         ...
# 3115            67      34          263        59    41          41
# 3116            58      39          255        61    47          38
# 3117            24      11           80         9    16          15
# 3118            45      36          201        51    40          30
# 3119            74      45          333        77    64          48
#
#      long_passing ball_control  total_movement acceleration sprint_speed  \
# 0              81           90             313           50           48
# 1              65           68             366           76           69
# 2              75           85             429           85           85
# 3              65           66             356           77           68
# 4              79           81             380           75           69
# ...           ...          ...             ...          ...          ...
# 3115           59           63             310           66           63
# 3116           53           56             341           74           76
# 3117           25           15             196           20           31
# 3118           31           49             290           62           65
# 3119           68           76             376           76           74
#
#      agility reactions balance  total_power shot_power jumping stamina  \
# 0         73        70      72          314         74      55      41
# 1         81        61      79          272         62      56      63
# 2         89        79      91          332         73      60      68
# 3         78        59      74          267         48      58      63
# 4         82        69      85          308         72      50      70
# ...      ...       ...     ...          ...        ...     ...     ...
# 3115      64        62      55          288         50      59      76
# 3116      64        61      66          273         38      69      62
# 3117      38        57      50          220         52    58+1      27
# 3118      58        54      51          292         51      64      60
# 3119      82        70      74          372         71      79      90
#
#      strength long_shots  total_mentality aggression interceptions  \
# 0          72         72              319         60            25
# 1          47         44              264         41            37
# 2          55         76              294         44            33
# 3          51         47              263         47            54
# 4          43         73              316         42            55
# ...       ...        ...              ...        ...           ...
# 3115       59         44              285         59            63
# 3116       68         36              256         64            58
# 3117       71         12              105         27            15
# 3118       64         53              203         29            10
# 3119       76         56              320         73            72
#
#      att._position vision penalties composure  total_defending  \
# 0               66     82        86         0               78
# 1               60     65        61        63              140
# 2               78     81        58        79               84
# 3               54     59        49        49              161
# 4               68     80        71        77              155
# ...            ...    ...       ...       ...              ...
# 3115            53     60        50        57              193
# 3116            44     45        45        55              172
# 3117             8     41        14        37               47
# 3118            55     51        58        48               46
# 3119            56     67        52        75              203
#
#      defensive_awareness standing_tackle sliding_tackle  total_goalkeeping  \
# 0                     25              28             25                 54
# 1                     40              49             51                 39
# 2                     40              23             21                 51
# 3                     50              55             56                 48
# 4                     52              57             46                 58
# ...                  ...             ...            ...                ...
# 3115                  65              66             62                 62
# 3116                  57              58             57                 54
# 3117                  20              14             13                348
# 3118                  19              15             12                 53
# 3119                  65              71             67                 50
#
#      gk_diving gk_handling gk_kicking gk_positioning gk_reflexes  total_stats  \
# 0            7          14         13              6          14         1875
# 1           10           7          9              5           8         1651
# 2           13           9         13             10           6         1897
# 3            9          13          7             11           8         1644
# 4           13          10         11             14          10         1960
# ...        ...         ...        ...            ...         ...          ...
# 3115        13          11         13             11          14         1655
# 3116         8          13         13             13           7         1592
# 3117      70+1        68+1         69           69+1        72+1         1066
# 3118         6           9         11             14          13         1308
# 3119         8          15          7              6          14         1947
#
#       base_stats  international_reputation  pace_diving  shooting_handling  \
# 0            377                         3           49                 72
# 1            351                         1           72                 54
# 2            409                         1           85                 74
# 3            353                         1           72                 50
# 4            405                         1           72                 70
# ...          ...                       ...          ...                ...
# 3115         357                         1           64                 46
# 3116         347                         1           75                 35
# 3117         372                         1           70                 68
# 3118         283                         1           64                 53
# 3119         425                         1           75                 59
#
#       passing_kicking  dribbling_reflexes  defending_pace  \
# 0                  83                  84              28
# 1                  61                  70              44
# 2                  78                  85              31
# 3                  59                  66              52
# 4                  80                  81              52
# ...               ...                 ...             ...
# 3115               60                  61              63
# 3116               54                  60              57
# 3117               69                  72              24
# 3118               40                  51              19
# 3119               67                  77              68
#
#                 player_name position
# 0                Ronaldinho  CAM, ST
# 1             O. Hutchinson  RM, CAM
# 2                    Brahim      CAM
# 3                 K. Wätjen       CM
# 4                  A. Güler  CAM, RM
# ...                     ...      ...
# 3115                M. Wörl  CDM, CM
# 3116  F. Di Michele Sanchez      LWB
# 3117                 Aceves       GK
# 3118             T. Walczak       ST
# 3119           A. Makoumbou  CDM, CM
#
# [3120 rows x 65 columns]

# %%
#Calcular el numero de posiciones en las que cada jugador puede jugar y representarlo en un histograma
df['no_of_playable_positions'] = df.position.apply(lambda x: len(x.split(','))).astype(int)
sns.histplot(df['no_of_playable_positions'])
# Out:
# <Axes: xlabel='no_of_playable_positions', ylabel='Count'>

# %% [markdown]
# Como el objetivo es pordecir el valor de mercado de jugadores de fútbol, la cantidad de posiciones en las que juega puede ser una variable importante en el modelo. Es decir, el modelo de Machine Learning podría aprender si la polivalencia para poder jugar en varias posiciones, tiene un impacto positivo o negativo a la hora de valorar a un jugador.
#
# Una vez separada la columna "name" en dos, podemos visualizar en un histograma la distribución de jugadores según su polivalencia en las posiciones.
#
# Viendo los resultados de dicho histograma, se observa que la mayoría de los jugadores en el dataset tienen 1 o 2 posiciones principales, con una cantidad similar en ambas categorías. Mientras que los jugadores que pueden jugar en 3 posiciones es un grupo mas pequeños.

# %%
#Divido la columna en equipo y años de contrato
df[['team', 'contract']] = df['team_&_contract'].str.split('\n', expand=True)

#Creo una columna que almacena el año de inicio del contrato
df['contract_start'] = df['contract'].str.split(' ~ ').str[0]
#Creo una columna que almacena el año de finalizacion del contrato
df['contract_end'] = df['contract'].str.split(' ~ ').str[-1]

#En la columna contract_end puede haber texto adicional, por lo tanto se limpia dicha columna.
#En el caso de que la columna tenga texto adicional (es decir que sea texto), me quedo con los ultimos 4 caracteres
df['contract_end'] = df['contract_end'].apply(lambda x: x if x.isdigit() else x[-4:])
df.drop(['team_&_contract', 'contract'], axis=1, inplace=True)

df.head()
# Out:
#    age overall_rating potential      id         height         weight   foot  \
# 0   34             78        78   28130   182cm / 6'0"  76kg / 168lbs  Right
# 1   19             65        81  260145   174cm / 5'9"  65kg / 143lbs   Left
# 2   23             82        86  231410   170cm / 5'7"  68kg / 150lbs  Right
# 3   17             62        80   70728  178cm / 5'10"  72kg / 159lbs  Right
# 4   18             77        88  264309   175cm / 5'9"  70kg / 154lbs   Left
#
#    best_overall best_position  growth   value   wage release_clause  \
# 0            77           CAM       0   €4.1M   €45K             €0
# 1            67           CAM      16   €1.8M    €3K          €4.5M
# 2            84           CAM       4  €43.5M  €145K         €92.4M
# 3            65           CAM      18     €1M   €900          €2.3M
# 4            79           CAM      11    €22M   €41K         €49.5M
#
#    total_attacking crossing finishing heading_accuracy short_passing volleys  \
# 0              367       84        69               50            82      82
# 1              266       48        53               49            66      50
# 2              328       75        76               30            83      64
# 3              257       48        53               45            67      44
# 4              340       80        68               41            81      70
#
#    total_skill dribbling curve fk_accuracy long_passing ball_control  \
# 0          430        86    86          87           81           90
# 1          304        69    52          50           65           68
# 2          379        84    74          61           75           85
# 3          292        66    52          43           65           66
# 4          403        83    84          76           79           81
#
#    total_movement acceleration sprint_speed agility reactions balance  \
# 0             313           50           48      73        70      72
# 1             366           76           69      81        61      79
# 2             429           85           85      89        79      91
# 3             356           77           68      78        59      74
# 4             380           75           69      82        69      85
#
#    total_power shot_power jumping stamina strength long_shots  \
# 0          314         74      55      41       72         72
# 1          272         62      56      63       47         44
# 2          332         73      60      68       55         76
# 3          267         48      58      63       51         47
# 4          308         72      50      70       43         73
#
#    total_mentality aggression interceptions att._position vision penalties  \
# 0              319         60            25            66     82        86
# 1              264         41            37            60     65        61
# 2              294         44            33            78     81        58
# 3              263         47            54            54     59        49
# 4              316         42            55            68     80        71
#
#   composure  total_defending defensive_awareness standing_tackle  \
# 0         0               78                  25              28
# 1        63              140                  40              49
# 2        79               84                  40              23
# 3        49              161                  50              55
# 4        77              155                  52              57
#
#   sliding_tackle  total_goalkeeping gk_diving gk_handling gk_kicking  \
# 0             25                 54         7          14         13
# 1             51                 39        10           7          9
# 2             21                 51        13           9         13
# 3             56                 48         9          13          7
# 4             46                 58        13          10         11
#
#   gk_positioning gk_reflexes  total_stats  base_stats  \
# 0              6          14         1875         377
# 1              5           8         1651         351
# 2             10           6         1897         409
# 3             11           8         1644         353
# 4             14          10         1960         405
#
#    international_reputation  pace_diving  shooting_handling  passing_kicking  \
# 0                         3           49                 72               83
# 1                         1           72                 54               61
# 2                         1           85                 74               78
# 3                         1           72                 50               59
# 4                         1           72                 70               80
#
#    dribbling_reflexes  defending_pace    player_name position  \
# 0                  84              28     Ronaldinho  CAM, ST
# 1                  70              44  O. Hutchinson  RM, CAM
# 2                  85              31         Brahim      CAM
# 3                  66              52      K. Wätjen       CM
# 4                  81              52       A. Güler  CAM, RM
#
#    no_of_playable_positions               team contract_start contract_end
# 0                         2          Querétaro           2014         2016
# 1                         2       Ipswich Town           2022         2025
# 2                         1        Real Madrid           2019         2027
# 3                         1  Borussia Dortmund           2024         2028
# 4                         2        Real Madrid           2023         2029

# %% [markdown]
# Con esta limpieza en la columna team&contract, se consigue separar la información en columnas específicas para así, optimizar la organización del dataset. Antes, toda la columna era de tipo "String", con lo que era mucho más dificil el poder trabajar con los años de contrato, en el caso que queramos analizar dichos valores.

# %%
print(df['contract_start'].dtype)
# Out:
# object

# %%
print(df['contract_end'].dtype)
# Out:
# object

# %%
df
# Out:
#       age overall_rating potential      id         height         weight  \
# 0      34             78        78   28130   182cm / 6'0"  76kg / 168lbs
# 1      19             65        81  260145   174cm / 5'9"  65kg / 143lbs
# 2      23             82        86  231410   170cm / 5'7"  68kg / 150lbs
# 3      17             62        80   70728  178cm / 5'10"  72kg / 159lbs
# 4      18             77        88  264309   175cm / 5'9"  70kg / 154lbs
# ...   ...            ...       ...     ...            ...            ...
# 3115   19             65        78  270403  178cm / 5'10"  69kg / 152lbs
# 3116   20             62        72  270461  180cm / 5'11"  81kg / 179lbs
# 3117   19           69+1      82+1  270529   190cm / 6'3"  85kg / 187lbs
# 3118   17             54        69  270594   189cm / 6'2"  88kg / 194lbs
# 3119   24             73        78  270597   187cm / 6'2"  80kg / 176lbs
#
#        foot  best_overall best_position  growth   value   wage release_clause  \
# 0     Right            77           CAM       0   €4.1M   €45K             €0
# 1      Left            67           CAM      16   €1.8M    €3K          €4.5M
# 2     Right            84           CAM       4  €43.5M  €145K         €92.4M
# 3     Right            65           CAM      18     €1M   €900          €2.3M
# 4      Left            79           CAM      11    €22M   €41K         €49.5M
# ...     ...           ...           ...     ...     ...    ...            ...
# 3115  Right            66           CDM      13   €1.6M    €3K             €0
# 3116   Left            62           LWB      10   €825K    €1K          €1.4M
# 3117  Right            69            GK      13   €2.9M    €2K             €0
# 3118  Right            56            ST      15   €250K   €500          €506K
# 3119  Right            74           CDM       5   €4.2M   €16K          €7.9M
#
#       total_attacking crossing finishing heading_accuracy short_passing  \
# 0                 367       84        69               50            82
# 1                 266       48        53               49            66
# 2                 328       75        76               30            83
# 3                 257       48        53               45            67
# 4                 340       80        68               41            81
# ...               ...      ...       ...              ...           ...
# 3115              254       58        45               50            67
# 3116              241       60        30               54            58
# 3117               70       15        10               10            24
# 3118              223       31        55               56            45
# 3119              293       57        57               60            74
#
#      volleys  total_skill dribbling curve fk_accuracy long_passing  \
# 0         82          430        86    86          87           81
# 1         50          304        69    52          50           65
# 2         64          379        84    74          61           75
# 3         44          292        66    52          43           65
# 4         70          403        83    84          76           79
# ...      ...          ...       ...   ...         ...          ...
# 3115      34          263        59    41          41           59
# 3116      39          255        61    47          38           53
# 3117      11           80         9    16          15           25
# 3118      36          201        51    40          30           31
# 3119      45          333        77    64          48           68
#
#      ball_control  total_movement acceleration sprint_speed agility reactions  \
# 0              90             313           50           48      73        70
# 1              68             366           76           69      81        61
# 2              85             429           85           85      89        79
# 3              66             356           77           68      78        59
# 4              81             380           75           69      82        69
# ...           ...             ...          ...          ...     ...       ...
# 3115           63             310           66           63      64        62
# 3116           56             341           74           76      64        61
# 3117           15             196           20           31      38        57
# 3118           49             290           62           65      58        54
# 3119           76             376           76           74      82        70
#
#      balance  total_power shot_power jumping stamina strength long_shots  \
# 0         72          314         74      55      41       72         72
# 1         79          272         62      56      63       47         44
# 2         91          332         73      60      68       55         76
# 3         74          267         48      58      63       51         47
# 4         85          308         72      50      70       43         73
# ...      ...          ...        ...     ...     ...      ...        ...
# 3115      55          288         50      59      76       59         44
# 3116      66          273         38      69      62       68         36
# 3117      50          220         52    58+1      27       71         12
# 3118      51          292         51      64      60       64         53
# 3119      74          372         71      79      90       76         56
#
#       total_mentality aggression interceptions att._position vision penalties  \
# 0                 319         60            25            66     82        86
# 1                 264         41            37            60     65        61
# 2                 294         44            33            78     81        58
# 3                 263         47            54            54     59        49
# 4                 316         42            55            68     80        71
# ...               ...        ...           ...           ...    ...       ...
# 3115              285         59            63            53     60        50
# 3116              256         64            58            44     45        45
# 3117              105         27            15             8     41        14
# 3118              203         29            10            55     51        58
# 3119              320         73            72            56     67        52
#
#      composure  total_defending defensive_awareness standing_tackle  \
# 0            0               78                  25              28
# 1           63              140                  40              49
# 2           79               84                  40              23
# 3           49              161                  50              55
# 4           77              155                  52              57
# ...        ...              ...                 ...             ...
# 3115        57              193                  65              66
# 3116        55              172                  57              58
# 3117        37               47                  20              14
# 3118        48               46                  19              15
# 3119        75              203                  65              71
#
#      sliding_tackle  total_goalkeeping gk_diving gk_handling gk_kicking  \
# 0                25                 54         7          14         13
# 1                51                 39        10           7          9
# 2                21                 51        13           9         13
# 3                56                 48         9          13          7
# 4                46                 58        13          10         11
# ...             ...                ...       ...         ...        ...
# 3115             62                 62        13          11         13
# 3116             57                 54         8          13         13
# 3117             13                348      70+1        68+1         69
# 3118             12                 53         6           9         11
# 3119             67                 50         8          15          7
#
#      gk_positioning gk_reflexes  total_stats  base_stats  \
# 0                 6          14         1875         377
# 1                 5           8         1651         351
# 2                10           6         1897         409
# 3                11           8         1644         353
# 4                14          10         1960         405
# ...             ...         ...          ...         ...
# 3115             11          14         1655         357
# 3116             13           7         1592         347
# 3117           69+1        72+1         1066         372
# 3118             14          13         1308         283
# 3119              6          14         1947         425
#
#       international_reputation  pace_diving  shooting_handling  \
# 0                            3           49                 72
# 1                            1           72                 54
# 2                            1           85                 74
# 3                            1           72                 50
# 4                            1           72                 70
# ...                        ...          ...                ...
# 3115                         1           64                 46
# 3116                         1           75                 35
# 3117                         1           70                 68
# 3118                         1           64                 53
# 3119                         1           75                 59
#
#       passing_kicking  dribbling_reflexes  defending_pace  \
# 0                  83                  84              28
# 1                  61                  70              44
# 2                  78                  85              31
# 3                  59                  66              52
# 4                  80                  81              52
# ...               ...                 ...             ...
# 3115               60                  61              63
# 3116               54                  60              57
# 3117               69                  72              24
# 3118               40                  51              19
# 3119               67                  77              68
#
#                 player_name position  no_of_playable_positions  \
# 0                Ronaldinho  CAM, ST                         2
# 1             O. Hutchinson  RM, CAM                         2
# 2                    Brahim      CAM                         1
# 3                 K. Wätjen       CM                         1
# 4                  A. Güler  CAM, RM                         2
# ...                     ...      ...                       ...
# 3115                M. Wörl  CDM, CM                         2
# 3116  F. Di Michele Sanchez      LWB                         1
# 3117                 Aceves       GK                         1
# 3118             T. Walczak       ST                         1
# 3119           A. Makoumbou  CDM, CM                         2
#
#                        team        contract_start contract_end
# 0                 Querétaro                  2014         2016
# 1              Ipswich Town                  2022         2025
# 2               Real Madrid                  2019         2027
# 3         Borussia Dortmund                  2024         2028
# 4               Real Madrid                  2023         2029
# ...                     ...                   ...          ...
# 3115  DSC Arminia Bielefeld  Jun 30, 2024 On loan         loan
# 3116            Saarbrücken                  2023         2024
# 3117                Eldense  Jun 30, 2024 On loan         loan
# 3118      Raków Częstochowa                  2023         2026
# 3119               Cagliari                  2022         2026
#
# [3120 rows x 68 columns]

# %% [markdown]
# Una vez hecha la limpieza anterior y separar las columnas de los años de contrato, dichas columnas son de tipo object aún, ya que hay datos de tipo "string" como "loan". Por lo tanto, estas dos columnas necesitan una limpieza que haga que sean de tipo "int"

# %%
#Con este patrón, se buscarán valores que sean años de 4 dígitos y se ignorará cualquier otro texto 
#(como "loan", "Exp. in 2025", etc)
patron = r'^\d{4}$'

#Para cada una de las columnas, convierte el valor a texto y con el patron definido anteriormente, comprueba si coincide.
#Si coincide, axtrae el año y lo mantiene en la columna
#Si no coincide, reemplaza el valor por una cadena vacia
df['contract_start'] = df['contract_start'].apply(lambda x: re.match(patron, str(x)).group() 
                                                  if re.match(patron, str(x)) else '')
df['contract_end'] = df['contract_end'].apply(lambda x: re.match(patron, str(x)).group() 
                                              if re.match(patron, str(x)) else '')

#Teniendo las columnas como valores numericos, convierte los valores vacios a valores nulos (pd.to_numeric)
#Y despues los sustituye por valor 0, para asegurar que la columna sea numerica (.fillna(0))
df['contract_start'] = pd.to_numeric(df['contract_start'], errors='coerce').fillna(0).astype(int)
df['contract_end'] = pd.to_numeric(df['contract_end'], errors='coerce').fillna(0).astype(int)

# %%
print(df['contract_end'].dtype)
# Out:
# int32

# %%
print(df['contract_start'].dtype)
# Out:
# int32
